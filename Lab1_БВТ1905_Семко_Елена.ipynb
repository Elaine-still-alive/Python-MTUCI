# %% [markdown]
# # Лабораторная работа 1
# ## Выполнила студентка группы БВТ1905 Семко Елена
# ### Задание №1
# Вывести "Hello, world!"

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры m, n, min_limit, max_limit, где m и n указывают размер
# матрицы, а min_lim и max_lim - минимальное и максимальное значение для
# генерируемого числа

# %%
import random

# %%
u_m = input()
u_n = input()
u_min_lim = input()
u_max_lim = input()

# %%
if u_m == "":
    m = 50
else:
    m = int(u_m)
if u_n == "":
    n = 50
else:
    n = int(u_n)
if u_min_lim == "":
    min_lim = -250
else:
    min_lim = int(u_min_lim)
if u_max_lim == "":
    max_lim = 1018
else:
    max_lim = int(u_max_lim)
    
a = []
for i in range(n):
    a.append([0] * m)

# %%
for i in range(len(a)):
    for j in range(len(a[i])):
        a[i][j] = random.randint(min_lim, max_lim)

# %%
for i in range(len(a)):
    for j in range(len(a[i])):
       print(a[i][j], end=' ')
    print()
# Out:
# 855 801 695 -16 -33 -92 -145 726 -157 155 -198 865 35 984 139 -151 711 720 13 284 791 1007 676 453 37 253 474 1009 999 32 328 -127 109 987 697 77 1003 -236 167 732 -34 599 854 379 716 644 -37 249 671 476
# 220 873 350 726 -157 644 531 696 -195 703 -54 634 106 -4 420 1003 510 -47 912 469 -151 -58 4 536 -92 -123 261 352 517 345 770 569 910 171 -192 -54 32 288 420 931 127 453 1007 826 282 925 462 973 191 -35
# -39 520 209 -9 -6 -207 600 -173 282 272 458 -228 941 128 912 936 737 15 108 897 710 69 -33 1010 1018 122 492 610 74 894 527 7 602 -230 142 316 754 581 595 949 137 593 152 320 -109 328 68 284 -212 565
# 773 60 549 -47 880 281 577 723 -169 338 -11 471 96 50 411 97 389 660 714 -25 104 989 889 755 694 814 703 834 450 66 -197 -136 361 218 257 649 796 67 424 986 197 633 696 851 193 -157 270 267 343 571
# -157 847 168 882 720 271 62 641 136 843 365 977 -222 724 282 790 238 986 351 940 -221 440 -237 -196 492 770 452 753 482 939 653 500 90 857 527 350 -139 982 597 477 919 827 676 216 809 418 575 -202 37 453
# 688 695 -233 841 845 465 244 -72 -28 593 216 414 552 571 -28 419 -183 428 -107 253 168 279 992 516 440 911 896 543 409 704 700 544 220 817 -57 442 473 -229 96 758 564 -1 716 452 -41 467 187 259 689 -201
# 703 86 593 283 464 735 18 732 869 139 -11 915 156 514 335 819 739 626 -209 -205 -160 296 594 678 212 756 616 243 91 857 13 285 587 777 538 465 -220 756 -116 819 -156 810 181 330 539 847 943 -128 571 173
# 56 642 891 944 934 947 382 832 830 -229 75 232 288 599 351 396 -150 65 -118 367 693 308 784 609 71 714 957 821 316 293 553 148 673 -111 156 -161 -169 723 109 583 92 31 172 673 904 -173 227 355 136 425
# 363 0 234 626 746 1016 -174 975 55 812 836 603 426 860 649 590 -170 140 766 797 944 329 828 907 862 666 527 807 -128 883 711 543 893 824 55 -35 384 896 -237 -96 386 242 435 -64 -45 31 1010 490 54 166
# 999 992 -191 44 966 461 935 558 543 -212 837 543 283 663 167 -118 703 -183 603 430 421 740 622 317 926 -168 369 -78 226 48 384 742 793 523 -72 654 454 86 172 750 111 769 337 689 815 83 787 -129 303 975
# 4 892 461 880 175 698 477 629 971 -22 -201 229 986 167 959 426 -27 265 -3 -31 -204 862 315 780 89 592 438 217 898 283 -123 266 855 -191 714 582 438 282 821 318 68 -218 1014 916 531 24 -11 107 616 101

# %% [markdown]
# ### Задание 3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах

# %%
import copy
import time

# %%
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
arr_sort_1 = copy.deepcopy(a)
for i in range(len(arr_sort_1)):
    j = 0
    while j < len(arr_sort_1[i]) - 1:
        m = j
        k = j + 1
        while k < len(arr_sort_1[i]):
            if arr_sort_1[i][k] < arr_sort_1[i][m]:
                m = k
            k += 1
        arr_sort_1[i][j], arr_sort_1[i][m] = arr_sort_1[i][m], arr_sort_1[i][j]
        j += 1
    #print(arr_sort_1[i])
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.0658731460571289 s

# %%
# Сортировка вставкой.
start_time = time.time()
arr_sort_2 = copy.deepcopy(a)
for i in range (len(arr_sort_2)):
    for j in range(1, len(arr_sort_2[i])):
            key = arr_sort_2[i][j]
            k = j-1
            while k >= 0 and key < arr_sort_2[i][k] :
                arr_sort_2[i][k+1] = arr_sort_2[i][k]
                k -= 1
            arr_sort_2[i][k+1] = key
    #print(arr_sort_2[i])
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.04288649559020996 s

# %%
# Сортировка обменом. || Сортировка пузырьком.
start_time = time.time()
arr_sort_3 = copy.deepcopy(a)
for i in range(len(arr_sort_3)):
    for j in range(len(arr_sort_3[i])-1):
        for k in range(len(arr_sort_3[i])-j-1):
            if arr_sort_3[i][k] > arr_sort_3[i][k+1]:
                buff = arr_sort_3[i][k]
                arr_sort_3[i][k] = arr_sort_3[i][k+1]
                arr_sort_3[i][k+1] = buff
    #print(arr_sort_3[i])
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.07080960273742676 s

# %%
# Сортировка Шелла.
start_time = time.time()
arr_sort_4 = copy.deepcopy(a)
for i in range(len(arr_sort_4)):
    last_index = len(arr_sort_4) - 1
    step = len(arr_sort_4)//2
    while step > 0:
        for j in range(step, last_index + 1, 1):
            k = j
            delta = k - step
            while delta >= 0 and arr_sort_4[i][delta] > arr_sort_4[i][k]:
                arr_sort_4[i][delta], arr_sort_4[i][k] = arr_sort_4[i][k], arr_sort_4[i][delta]
                k = delta
                delta = k - step
        step //= 2
    #print(arr_sort_4[i])
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.03490591049194336 s

# %%
# Быстрая сортировка.
start_time = time.time()

arr_sort_5 = copy.deepcopy(a)

def quicksort(nums):
   if len(nums) <= 1:
       return nums
   else:
       q = random.choice(nums)
   l_nums = [n for n in nums if n < q]
 
   e_nums = [q] * nums.count(q)
   b_nums = [n for n in nums if n > q]
   return quicksort(l_nums) + e_nums + quicksort(b_nums)

for i in range(len(arr_sort_5)):
    arr_sort_5[i] = quicksort(arr_sort_5[i])
    #print(arr_sort_5[i])

print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.013962745666503906 s

# %%
#турнирная сортировка
start_time = time.time()

arr_sort_6 = copy.deepcopy(a)

def tour(ar):
    while len(ar) > 1:
        win_nums = []
        if len(ar) % 2 != 0:
            ar.append(max(ar)+1)
        for i in range(0, len(ar), 2):
            if ar[i] > ar[i+1]:
                win_nums.append(ar[i+1])
            else:
                win_nums.append(ar[i])
        ar = copy.copy(win_nums)
    return ar

def toursort(ar):
    sorted_arr = []
    while (len(ar) > 0):
        winner = tour(copy.copy(ar))[0]
        #print("{0} - removing {1}".format(ar, winner))
        ar.remove(winner)
        sorted_arr.append(winner)
    return sorted_arr
    
for i in range(len(arr_sort_6)):
    arr_sort_6[i] = toursort(arr_sort_6[i])
    #print(arr_sort_6[i])
    
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.06682276725769043 s

# %%
#пирамидальная сортировка
# Процедура для преобразования в двоичную кучу поддерева с корневым узлом i, что является индексом в arr[]. n - размер кучи
start_time = time.time()
arr_sort_7 = copy.deepcopy(a)
def heapify(arr_sort_7, n, i):
    largest = i # Initialize largest as root
    l = 2 * i + 1   # left = 2*i + 1
    r = 2 * i + 2   # right = 2*i + 2

  # Проверяем существует ли левый дочерний элемент больший, чем корень

    if l < n and arr_sort_7[i] < arr_sort_7[l]:
        largest = l

    # Проверяем существует ли правый дочерний элемент больший, чем корень

    if r < n and arr_sort_7[largest] < arr_sort_7[r]:
        largest = r

    # Заменяем корень, если нужно
    if largest != i:
        arr_sort_7[i],arr_sort_7[largest] = arr_sort_7[largest],arr_sort_7[i] # свап

        # Применяем heapify к корню.
        heapify(arr_sort_7, n, largest)

# Основная функция для сортировки массива заданного размера
def heapSort(arr_sort_7):
    n = len(arr_sort_7)

    # Построение max-heap.
    for i in range(n, -1, -1):
        heapify(arr_sort_7, n, i)

    # Один за другим извлекаем элементы
    for i in range(n-1, 0, -1):
        arr_sort_7[i], arr_sort_7[0] = arr_sort_7[0], arr_sort_7[i] # свап 
        heapify(arr_sort_7, i, 0)
print(" {0} s ".format(time.time() - start_time))
# Out:
#  0.02392888069152832 s
